# %%
from PIL import Image

pic = Image.open("/content/drive/MyDrive/Colab Files/pulsar.png")

pic
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=816x607 at 0x7FFBC85ED890>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def encrypt(img, msg, shift):
  px = img.load()
  xsize, ysize = img.size
  x, y, amsg, i = 0, 0, "", 0

  for char in msg:
    ascii = ord(char)+shift
    amsg+=chr(ascii)

  print(amsg)

  for x in range(0, xsize):
    for y in range(0, ysize):
      if px[x,y][0] == 255 and px[x,y][1] == 255 and px[x,y][2] == 255 and i < len(amsg):
        px[x,y]= (px[x,y][0], px[x,y][1], px[x,y][2], ord(amsg[i]))
        i+=1

  return

# %%
msg = "Hello, how are you doing today?"
encpic = pic.copy()
encrypt(encpic,msg, 5)
# Out:
# Mjqqt1%mt|%fwj%~tz%itnsl%ytif~D

# %%
encpic
# Out:
# <PIL.Image.Image image mode=RGBA size=816x607 at 0x7FFBC1F01150>

# %%
def decrypt(img, shift):
  px = img.load()
  xsize, ysize = img.size
  x, y, dm = 0, 0, ""

  for x in range(0, xsize):
    for y in range(0, ysize):
      if px[x,y][3] != 255:
        dm += chr(px[x,y][3]-shift)

  return dm

# %%
decrypt(encpic, 5)
# Out:
# 'Hello, how are you doing today?'
